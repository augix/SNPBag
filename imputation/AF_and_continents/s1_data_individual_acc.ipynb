# %%
outdir = './s1_result'
import pandas as pd
import os
os.makedirs(outdir, exist_ok=True)

# %%
def get_individual_acc(fn, method, ref):
    df = pd.read_csv(fn, sep='\t')
    print('df.head():\n', df.head())

    # get the sum of num_correct and num_total for each individual
    df1 = df.groupby('sample')['num_correct'].sum().reset_index()
    df2 = df.groupby('sample')['num_total'].sum().reset_index()
    # merge df1 and df2
    df_grouped = pd.merge(df1, df2, on='sample')
    df_grouped['accuracy'] = df_grouped['num_correct'] / df_grouped['num_total'] * 100
    df_grouped['method'] = method
    df_grouped['ref'] = ref
    # add continent info by using df['sample'] and df['continent']
    id2continent = df[['sample', 'continent']].set_index('sample')['continent'].to_dict()
    df_grouped['continent'] = df_grouped['sample'].map(id2continent)
    print('df_grouped.head():\n', df_grouped.head())
    return df_grouped

all_dfs = []
for method in ['snpbag_base', 'snpbag_ft_omni']:
    fn = f'./s0_result/{method}.tsv'
    ref = method
    df_grouped = get_individual_acc(fn, method, ref)
    all_dfs.append(df_grouped)

phasings = ['beagle', 'shapeit', 'eagle']
imputations = ['beagle', 'minimac', 'impute']
refs = ['noREF', 'REF']
for phasing in phasings:
    for imputation in imputations:
        for ref in refs:
            method = f'{phasing}_{ref}_{imputation}'
            fn = f'./s0_result/{method}.tsv'
            df_grouped = get_individual_acc(fn, method, ref)
            df_grouped['method'] = method
            all_dfs.append(df_grouped)

df_all = pd.concat(all_dfs)
print('df_all.head():\n', df_all.head())

# save
df_all.to_csv(os.path.join(outdir, 'individual_acc.tsv'), sep='\t', index=False)
# Out:
# df.head():
#     sample       maf_bin  num_wrong  num_correct  num_total  accuracy continent
# 0       0  [0.01, 0.03)        216         9084       9300  0.976774    EUROPE
# 1       0  [0.03, 0.06)        192        10127      10319  0.981394    EUROPE
# 2       0   [0.06, 0.1)        216        10236      10452  0.979334    EUROPE
# 3       0   [0.1, 0.18)        321        12577      12898  0.975112    EUROPE
# 4       0   [0.18, 0.3)        407        11261      11668  0.965118    EUROPE
# df_grouped.head():
#     sample  num_correct  num_total   accuracy       method          ref  \
# 0       0        63679      65690  96.938651  snpbag_base  snpbag_base
# 1       1        63790      65690  97.107627  snpbag_base  snpbag_base
# 2       2        63703      65690  96.975186  snpbag_base  snpbag_base
# 3       3        63999      65690  97.425788  snpbag_base  snpbag_base
# 4       4        64212      65690  97.750038  snpbag_base  snpbag_base
#
#             continent
# 0              EUROPE
# 1              EUROPE
# 2              EUROPE
# 3              EUROPE
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#     sample       maf_bin  num_wrong  num_correct  num_total  accuracy continent
# 0       0  [0.01, 0.03)        195         9105       9300  0.979032    EUROPE
# 1       0  [0.03, 0.06)        172        10147      10319  0.983332    EUROPE
# 2       0   [0.06, 0.1)        176        10276      10452  0.983161    EUROPE
# 3       0   [0.1, 0.18)        280        12618      12898  0.978291    EUROPE
# 4       0   [0.18, 0.3)        334        11334      11668  0.971375    EUROPE
# df_grouped.head():
#     sample  num_correct  num_total   accuracy          method             ref  \
# 0       0        64028      65690  97.469935  snpbag_ft_omni  snpbag_ft_omni
# 1       1        64020      65690  97.457756  snpbag_ft_omni  snpbag_ft_omni
# 2       2        63952      65690  97.354240  snpbag_ft_omni  snpbag_ft_omni
# 3       3        64192      65690  97.719592  snpbag_ft_omni  snpbag_ft_omni
# 4       4        64301      65690  97.885523  snpbag_ft_omni  snpbag_ft_omni
#
#             continent
# 0              EUROPE
# 1              EUROPE
# 2              EUROPE
# 3              EUROPE
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9078        221       9299  0.976234
# 1  HGDP00001  [0.03, 0.06)        10099        220      10319  0.978680
# 2  HGDP00001   [0.06, 0.1)        10261        190      10451  0.981820
# 3  HGDP00001   [0.1, 0.18)        12596        302      12898  0.976586
# 4  HGDP00001   [0.18, 0.3)        11236        432      11668  0.962976
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy               method    ref  \
# 0  HGDP00001        63691      65687  96.961347  beagle_noREF_beagle  noREF
# 1  HGDP00021        63461      65687  96.611202  beagle_noREF_beagle  noREF
# 2  HGDP00023        63512      65687  96.688843  beagle_noREF_beagle  noREF
# 3  HGDP00039        63812      65687  97.145554  beagle_noREF_beagle  noREF
# 4  HGDP00052        63595      65687  96.815199  beagle_noREF_beagle  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9079        220       9299  0.976342
# 1  HGDP00001  [0.03, 0.06)        10117        202      10319  0.980424
# 2  HGDP00001   [0.06, 0.1)        10268        183      10451  0.982490
# 3  HGDP00001   [0.1, 0.18)        12608        290      12898  0.977516
# 4  HGDP00001   [0.18, 0.3)        11300        368      11668  0.968461
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy             method  ref  \
# 0  HGDP00001        63855      65687  97.211016  beagle_REF_beagle  REF
# 1  HGDP00021        63424      65687  96.554874  beagle_REF_beagle  REF
# 2  HGDP00023        63741      65687  97.037466  beagle_REF_beagle  REF
# 3  HGDP00039        64049      65687  97.506356  beagle_REF_beagle  REF
# 4  HGDP00052        63601      65687  96.824334  beagle_REF_beagle  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9055        244       9299  0.973761
# 1  HGDP00001  [0.03, 0.06)        10045        274      10319  0.973447
# 2  HGDP00001   [0.06, 0.1)        10169        282      10451  0.973017
# 3  HGDP00001   [0.1, 0.18)        12532        366      12898  0.971624
# 4  HGDP00001   [0.18, 0.3)        11121        547      11668  0.953120
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy                method    ref  \
# 0  HGDP00001        63201      65687  96.215385  beagle_noREF_minimac  noREF
# 1  HGDP00021        63266      65687  96.314339  beagle_noREF_minimac  noREF
# 2  HGDP00023        63226      65687  96.253444  beagle_noREF_minimac  noREF
# 3  HGDP00039        63659      65687  96.912631  beagle_noREF_minimac  noREF
# 4  HGDP00052        63364      65687  96.463532  beagle_noREF_minimac  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9048        251       9299  0.973008
# 1  HGDP00001  [0.03, 0.06)        10113        206      10319  0.980037
# 2  HGDP00001   [0.06, 0.1)        10174        277      10451  0.973495
# 3  HGDP00001   [0.1, 0.18)        12542        356      12898  0.972399
# 4  HGDP00001   [0.18, 0.3)        11193        475      11668  0.959290
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy              method  ref  \
# 0  HGDP00001        63430      65687  96.564008  beagle_REF_minimac  REF
# 1  HGDP00021        63194      65687  96.204728  beagle_REF_minimac  REF
# 2  HGDP00023        63401      65687  96.519859  beagle_REF_minimac  REF
# 3  HGDP00039        63844      65687  97.194270  beagle_REF_minimac  REF
# 4  HGDP00052        63360      65687  96.457442  beagle_REF_minimac  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9089        210       9299  0.977417
# 1  HGDP00001  [0.03, 0.06)        10109        210      10319  0.979649
# 2  HGDP00001   [0.06, 0.1)        10272        179      10451  0.982872
# 3  HGDP00001   [0.1, 0.18)        12624        274      12898  0.978756
# 4  HGDP00001   [0.18, 0.3)        11274        394      11668  0.966232
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy               method    ref  \
# 0  HGDP00001        63814      65687  97.148599  beagle_noREF_impute  noREF
# 1  HGDP00021        63606      65687  96.831945  beagle_noREF_impute  noREF
# 2  HGDP00023        63864      65687  97.224717  beagle_noREF_impute  noREF
# 3  HGDP00039        63953      65687  97.360208  beagle_noREF_impute  noREF
# 4  HGDP00052        63726      65687  97.014630  beagle_noREF_impute  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9082        217       9299  0.976664
# 1  HGDP00001  [0.03, 0.06)        10130        189      10319  0.981684
# 2  HGDP00001   [0.06, 0.1)        10277        174      10451  0.983351
# 3  HGDP00001   [0.1, 0.18)        12632        266      12898  0.979377
# 4  HGDP00001   [0.18, 0.3)        11285        383      11668  0.967175
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy             method  ref  \
# 0  HGDP00001        63891      65687  97.265821  beagle_REF_impute  REF
# 1  HGDP00021        63754      65687  97.057256  beagle_REF_impute  REF
# 2  HGDP00023        63930      65687  97.325194  beagle_REF_impute  REF
# 3  HGDP00039        64148      65687  97.657071  beagle_REF_impute  REF
# 4  HGDP00052        63782      65687  97.099883  beagle_REF_impute  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9090        209       9299  0.977524
# 1  HGDP00001  [0.03, 0.06)        10092        227      10319  0.978002
# 2  HGDP00001   [0.06, 0.1)        10246        205      10451  0.980385
# 3  HGDP00001   [0.1, 0.18)        12603        295      12898  0.977128
# 4  HGDP00001   [0.18, 0.3)        11246        422      11668  0.963833
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy                method    ref  \
# 0  HGDP00001        63732      65687  97.023764  shapeit_noREF_beagle  noREF
# 1  HGDP00021        63422      65687  96.551829  shapeit_noREF_beagle  noREF
# 2  HGDP00023        63804      65687  97.133375  shapeit_noREF_beagle  noREF
# 3  HGDP00039        63875      65687  97.241463  shapeit_noREF_beagle  noREF
# 4  HGDP00052        63475      65687  96.632515  shapeit_noREF_beagle  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9090        209       9299  0.977524
# 1  HGDP00001  [0.03, 0.06)        10133        186      10319  0.981975
# 2  HGDP00001   [0.06, 0.1)        10275        176      10451  0.983160
# 3  HGDP00001   [0.1, 0.18)        12649        249      12898  0.980695
# 4  HGDP00001   [0.18, 0.3)        11285        383      11668  0.967175
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy              method  ref  \
# 0  HGDP00001        63949      65687  97.354119  shapeit_REF_beagle  REF
# 1  HGDP00021        63457      65687  96.605112  shapeit_REF_beagle  REF
# 2  HGDP00023        63729      65687  97.019197  shapeit_REF_beagle  REF
# 3  HGDP00039        63938      65687  97.337373  shapeit_REF_beagle  REF
# 4  HGDP00052        63535      65687  96.723857  shapeit_REF_beagle  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9071        228       9299  0.975481
# 1  HGDP00001  [0.03, 0.06)        10084        235      10319  0.977226
# 2  HGDP00001   [0.06, 0.1)        10194        257      10451  0.975409
# 3  HGDP00001   [0.1, 0.18)        12555        343      12898  0.973407
# 4  HGDP00001   [0.18, 0.3)        11199        469      11668  0.959805
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy                 method    ref  \
# 0  HGDP00001        63571      65687  96.778662  shapeit_noREF_minimac  noREF
# 1  HGDP00021        63348      65687  96.439174  shapeit_noREF_minimac  noREF
# 2  HGDP00023        63506      65687  96.679708  shapeit_noREF_minimac  noREF
# 3  HGDP00039        63648      65687  96.895885  shapeit_noREF_minimac  noREF
# 4  HGDP00052        63292      65687  96.353921  shapeit_noREF_minimac  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9060        239       9299  0.974298
# 1  HGDP00001  [0.03, 0.06)        10114        205      10319  0.980134
# 2  HGDP00001   [0.06, 0.1)        10184        267      10451  0.974452
# 3  HGDP00001   [0.1, 0.18)        12562        336      12898  0.973949
# 4  HGDP00001   [0.18, 0.3)        11171        497      11668  0.957405
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy               method  ref  \
# 0  HGDP00001        63504      65687  96.676664  shapeit_REF_minimac  REF
# 1  HGDP00021        63275      65687  96.328041  shapeit_REF_minimac  REF
# 2  HGDP00023        63515      65687  96.693410  shapeit_REF_minimac  REF
# 3  HGDP00039        63852      65687  97.206449  shapeit_REF_minimac  REF
# 4  HGDP00052        63445      65687  96.586844  shapeit_REF_minimac  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9091        208       9299  0.977632
# 1  HGDP00001  [0.03, 0.06)        10113        206      10319  0.980037
# 2  HGDP00001   [0.06, 0.1)        10270        181      10451  0.982681
# 3  HGDP00001   [0.1, 0.18)        12623        275      12898  0.978679
# 4  HGDP00001   [0.18, 0.3)        11270        398      11668  0.965890
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy                method    ref  \
# 0  HGDP00001        63789      65687  97.110539  shapeit_noREF_impute  noREF
# 1  HGDP00021        63617      65687  96.848692  shapeit_noREF_impute  noREF
# 2  HGDP00023        63902      65687  97.282567  shapeit_noREF_impute  noREF
# 3  HGDP00039        64028      65687  97.474386  shapeit_noREF_impute  noREF
# 4  HGDP00052        63647      65687  96.894363  shapeit_noREF_impute  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9105        194       9299  0.979138
# 1  HGDP00001  [0.03, 0.06)        10145        174      10319  0.983138
# 2  HGDP00001   [0.06, 0.1)        10281        170      10451  0.983734
# 3  HGDP00001   [0.1, 0.18)        12648        250      12898  0.980617
# 4  HGDP00001   [0.18, 0.3)        11309        359      11668  0.969232
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy              method  ref  \
# 0  HGDP00001        63989      65687  97.415014  shapeit_REF_impute  REF
# 1  HGDP00021        63706      65687  96.984183  shapeit_REF_impute  REF
# 2  HGDP00023        63889      65687  97.262777  shapeit_REF_impute  REF
# 3  HGDP00039        64104      65687  97.590086  shapeit_REF_impute  REF
# 4  HGDP00052        63766      65687  97.075525  shapeit_REF_impute  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9085        214       9299  0.976987
# 1  HGDP00001  [0.03, 0.06)        10085        234      10319  0.977323
# 2  HGDP00001   [0.06, 0.1)        10231        220      10451  0.978949
# 3  HGDP00001   [0.1, 0.18)        12565        333      12898  0.974182
# 4  HGDP00001   [0.18, 0.3)        11240        428      11668  0.963318
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy              method    ref  \
# 0  HGDP00001        63595      65687  96.815199  eagle_noREF_beagle  noREF
# 1  HGDP00021        63462      65687  96.612724  eagle_noREF_beagle  noREF
# 2  HGDP00023        63581      65687  96.793886  eagle_noREF_beagle  noREF
# 3  HGDP00039        63877      65687  97.244508  eagle_noREF_beagle  noREF
# 4  HGDP00052        63427      65687  96.559441  eagle_noREF_beagle  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9100        199       9299  0.978600
# 1  HGDP00001  [0.03, 0.06)        10121        198      10319  0.980812
# 2  HGDP00001   [0.06, 0.1)        10272        179      10451  0.982872
# 3  HGDP00001   [0.1, 0.18)        12640        258      12898  0.979997
# 4  HGDP00001   [0.18, 0.3)        11269        399      11668  0.965804
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy            method  ref  \
# 0  HGDP00001        63883      65687  97.253642  eagle_REF_beagle  REF
# 1  HGDP00021        63360      65687  96.457442  eagle_REF_beagle  REF
# 2  HGDP00023        63747      65687  97.046600  eagle_REF_beagle  REF
# 3  HGDP00039        64056      65687  97.517012  eagle_REF_beagle  REF
# 4  HGDP00052        63621      65687  96.854781  eagle_REF_beagle  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9045        254       9299  0.972685
# 1  HGDP00001  [0.03, 0.06)        10065        254      10319  0.975385
# 2  HGDP00001   [0.06, 0.1)        10171        280      10451  0.973208
# 3  HGDP00001   [0.1, 0.18)        12461        437      12898  0.966119
# 4  HGDP00001   [0.18, 0.3)        11054        614      11668  0.947377
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy               method    ref  \
# 0  HGDP00001        63004      65687  95.915478  eagle_noREF_minimac  noREF
# 1  HGDP00021        63401      65687  96.519859  eagle_noREF_minimac  noREF
# 2  HGDP00023        63556      65687  96.755827  eagle_noREF_minimac  noREF
# 3  HGDP00039        63540      65687  96.731469  eagle_noREF_minimac  noREF
# 4  HGDP00052        63301      65687  96.367622  eagle_noREF_minimac  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9074        225       9299  0.975804
# 1  HGDP00001  [0.03, 0.06)        10113        206      10319  0.980037
# 2  HGDP00001   [0.06, 0.1)        10174        277      10451  0.973495
# 3  HGDP00001   [0.1, 0.18)        12584        314      12898  0.975655
# 4  HGDP00001   [0.18, 0.3)        11171        497      11668  0.957405
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy             method  ref  \
# 0  HGDP00001        63459      65687  96.608157  eagle_REF_minimac  REF
# 1  HGDP00021        63216      65687  96.238221  eagle_REF_minimac  REF
# 2  HGDP00023        63630      65687  96.868482  eagle_REF_minimac  REF
# 3  HGDP00039        63814      65687  97.148599  eagle_REF_minimac  REF
# 4  HGDP00052        63377      65687  96.483322  eagle_REF_minimac  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9086        213       9299  0.977094
# 1  HGDP00001  [0.03, 0.06)        10112        207      10319  0.979940
# 2  HGDP00001   [0.06, 0.1)        10259        192      10451  0.981629
# 3  HGDP00001   [0.1, 0.18)        12574        324      12898  0.974880
# 4  HGDP00001   [0.18, 0.3)        11232        436      11668  0.962633
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy              method    ref  \
# 0  HGDP00001        63631      65687  96.870005  eagle_noREF_impute  noREF
# 1  HGDP00021        63625      65687  96.860870  eagle_noREF_impute  noREF
# 2  HGDP00023        63823      65687  97.162300  eagle_noREF_impute  noREF
# 3  HGDP00039        64060      65687  97.523102  eagle_noREF_impute  noREF
# 4  HGDP00052        63679      65687  96.943079  eagle_noREF_impute  noREF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df.head():
#        sample       maf_bin  num_correct  num_wrong  num_total  accuracy  \
# 0  HGDP00001  [0.01, 0.03)         9103        196       9299  0.978922
# 1  HGDP00001  [0.03, 0.06)        10128        191      10319  0.981490
# 2  HGDP00001   [0.06, 0.1)        10280        171      10451  0.983638
# 3  HGDP00001   [0.1, 0.18)        12641        257      12898  0.980074
# 4  HGDP00001   [0.18, 0.3)        11271        397      11668  0.965975
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#        sample  num_correct  num_total   accuracy            method  ref  \
# 0  HGDP00001        63880      65687  97.249075  eagle_REF_impute  REF
# 1  HGDP00021        63696      65687  96.968959  eagle_REF_impute  REF
# 2  HGDP00023        63932      65687  97.328238  eagle_REF_impute  REF
# 3  HGDP00039        64117      65687  97.609877  eagle_REF_impute  REF
# 4  HGDP00052        63830      65687  97.172957  eagle_REF_impute  REF
#
#             continent
# 0  CENTRAL_SOUTH_ASIA
# 1  CENTRAL_SOUTH_ASIA
# 2  CENTRAL_SOUTH_ASIA
# 3  CENTRAL_SOUTH_ASIA
# 4  CENTRAL_SOUTH_ASIA
# df_all.head():
#    sample  num_correct  num_total   accuracy       method          ref  \
# 0      0        63679      65690  96.938651  snpbag_base  snpbag_base
# 1      1        63790      65690  97.107627  snpbag_base  snpbag_base
# 2      2        63703      65690  96.975186  snpbag_base  snpbag_base
# 3      3        63999      65690  97.425788  snpbag_base  snpbag_base
# 4      4        64212      65690  97.750038  snpbag_base  snpbag_base
#
#             continent
# 0              EUROPE
# 1              EUROPE
# 2              EUROPE
# 3              EUROPE
# 4  CENTRAL_SOUTH_ASIA

# %%
# read df_all
df_all = pd.read_csv('./s1_result/individual_acc.tsv', sep='\t')
print('df_all.head():\n', df_all.head())

# group by method
df_grouped = df_all.groupby('method')['accuracy'].mean().reset_index()
print('df_grouped.head():\n', df_grouped.head())

# sort by accuracy
df_grouped = df_grouped.sort_values('accuracy', ascending=False)
print('df_grouped:\n', df_grouped)
# Out:
# df_all.head():
#    sample  num_correct  num_total   accuracy       method          ref  \
# 0      0        63679      65690  96.938651  snpbag_base  snpbag_base
# 1      1        63790      65690  97.107627  snpbag_base  snpbag_base
# 2      2        63703      65690  96.975186  snpbag_base  snpbag_base
# 3      3        63999      65690  97.425788  snpbag_base  snpbag_base
# 4      4        64212      65690  97.750038  snpbag_base  snpbag_base
#
#             continent
# 0              EUROPE
# 1              EUROPE
# 2              EUROPE
# 3              EUROPE
# 4  CENTRAL_SOUTH_ASIA
# df_grouped.head():
#                  method   accuracy
# 0    beagle_REF_beagle  96.889034
# 1    beagle_REF_impute  97.104767
# 2   beagle_REF_minimac  96.582305
# 3  beagle_noREF_beagle  96.609707
# 4  beagle_noREF_impute  96.875361
# df_grouped:
#                     method   accuracy
# 19         snpbag_ft_omni  97.160731
# 1       beagle_REF_impute  97.104767
# 13     shapeit_REF_impute  97.087182
# 7        eagle_REF_impute  97.061091
# 16   shapeit_noREF_impute  96.902891
# 0       beagle_REF_beagle  96.889034
# 4     beagle_noREF_impute  96.875361
# 12     shapeit_REF_beagle  96.835716
# 10     eagle_noREF_impute  96.824489
# 6        eagle_REF_beagle  96.817800
# 18            snpbag_base  96.776618
# 15   shapeit_noREF_beagle  96.637667
# 3     beagle_noREF_beagle  96.609707
# 2      beagle_REF_minimac  96.582305
# 14    shapeit_REF_minimac  96.556833
# 9      eagle_noREF_beagle  96.546726
# 8       eagle_REF_minimac  96.529663
# 17  shapeit_noREF_minimac  96.317433
# 5    beagle_noREF_minimac  96.303535
# 11    eagle_noREF_minimac  96.246530

# %%
# plot the accuracy of each method as horizontal bars in reverse order
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
# Reverse the DataFrame order for plotting
df_grouped_rev = df_grouped.iloc[::-1]
bars = plt.barh(df_grouped_rev['method'], df_grouped_rev['accuracy'])
plt.xlabel('Mean Individual Accuracy')
plt.ylabel('Method')
plt.title('Mean Individual Accuracy by Method')
plt.yticks(rotation=0)
plt.tight_layout()
plt.xlim(95, 98)

# Add values at the bottom of each bar with white color
for bar, acc in zip(bars, df_grouped_rev['accuracy']):
    plt.text(
        bar.get_width() - 0.1,  # a little to the left of the bar end
        bar.get_y() + bar.get_height() / 2,
        f"{acc:.2f}",
        va='center',
        ha='right',
        color='white',
        fontsize=10,
        fontweight='bold'
    )

plt.show()
